# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from function import Eddies_Tools
import numpy as np

from nltk import FreqDist
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %% [markdown]
# ## Setup

# %%
# loading in data
trade_chat = pd.read_csv('data\\trade_chat_v3.csv', index_col=0)

# %%
# dropping duplicated and resetting index
trade_chat.drop_duplicates(subset= 'text', inplace=True)
trade_chat.reset_index(drop=True, inplace=True)

# %%
# loading in stopwords and adding data related stop words.
s_words = stopwords.words('english')
s_words.extend(['u','ur','im','dont','thats'])

# instancing RegEx Tokenizer
tokenizer = RegexpTokenizer(r"(?u)\b([a-z]+|9.2)\w*\b")

# instancing my tools
et = Eddies_Tools()

# %%
# tokenizing the trade_chat dataframe
tc_tokenized = et.nlp_tokenizer(trade_chat, tokenizer, s_words)

# %%
text = " ".join(chat for chat in tc_tokenized.text)
print ("There are {} words in the combination of all review.".format(len(text)))

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");
# Out:
# There are 140038 words in the combination of all review.

# %%
chat_tokenized = tc_tokenized[tc_tokenized.target == 'Chat']
patch_tokenized = tc_tokenized[tc_tokenized.target == 'Patch']
game_tokenized = tc_tokenized[tc_tokenized.target == 'Game']

# %%
neg_patch = patch_tokenized[patch_tokenized.sentiment == 'Negative']
neg_chat = chat_tokenized[chat_tokenized.sentiment == 'Negative']
neg_game = game_tokenized[game_tokenized.sentiment == 'Negative']
other_patch = patch_tokenized[patch_tokenized.sentiment == 'Other']
other_chat = chat_tokenized[chat_tokenized.sentiment == 'Other']
other_game = game_tokenized[game_tokenized.sentiment == 'Other']

# %%
patch_text = " ".join(chat for chat in patch_tokenized.joined_tokens)
print ("There are {} words in the combination of all review.".format(len(patch_text)))

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(patch_text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");
# Out:
# There are 16174 words in the combination of all review.

# %%
game_text = " ".join(chat for chat in game_tokenized.joined_tokens)
print ("There are {} words in the combination of all review.".format(len(game_text)))

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(game_text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");
# Out:
# There are 18314 words in the combination of all review.

# %%
chat_text = " ".join(chat for chat in chat_tokenized.joined_tokens)
print ("There are {} words in the combination of all review.".format(len(chat_text)))

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(chat_text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");
# Out:
# There are 21846 words in the combination of all review.

# %%
chat_text = " ".join(chat for chat in chat_tokenized.joined_tokens)
print ("There are {} words in the combination of all review.".format(len(chat_text)))

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(chat_text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");
# Out:
# There are 21846 words in the combination of all review.

# %%
neg_patch_text = " ".join(chat for chat in neg_patch.joined_tokens)
print ("There are {} words in the combination of all review.".format(len(neg_patch_text)))

# Create and generate a word cloud image:
wordcloud = WordCloud(max_font_size=70, colormap='crest', max_words=50, background_color=None, mode= "RGBA",include_numbers=True).generate(neg_patch_text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

wordcloud.to_file("images/neg_patch.png");
# Out:
# There are 6130 words in the combination of all review.

# %%
neg_game_text = " ".join(chat for chat in neg_game.joined_tokens)
print ("There are {} words in the combination of all review.".format(len(neg_game_text)))

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(neg_game_text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");
# Out:
# There are 3560 words in the combination of all review.

# %%
neg_chat_text = " ".join(chat for chat in neg_chat.joined_tokens)
print ("There are {} words in the combination of all review.".format(len(neg_chat_text)))

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(neg_chat_text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");
# Out:
# There are 2848 words in the combination of all review.
